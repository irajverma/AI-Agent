# %% [markdown]
# ### Langchain version v1

# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
def get_weather(city:str):
    """Get the weather for a city."""
    return f"The weather in {city} is sunny."
from langchain.agents import create_agent

agent = create_agent(
    model="groq:llama-3.3-70b-versatile",  # <--- Prefixed with groq:
    tools=[get_weather],
    system_prompt="You are a helpfull assistent."
)

# %%
response=agent.invoke({"messages":[{"role":"user","content":"What is the weather of New York."}]})

# %%
response["messages"][-1].content
# Out:
# "I've already provided the function call to get the weather for New York. The actual weather conditions would depend on the current time and date, which I don't have access to. If you need real-time information, I suggest checking a weather website or app for the most up-to-date forecast."
